# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer, MinMaxScaler
from scipy.spatial.distance import cosine


# Configuration
SIZE_BUCKETS = {
    'short': (0, 250),
    'medium': (250, 500),
    'long': (500, 700),
    'extra_long': (700, np.inf)
}

WEIGHTS = {
    'genre': 0.5,
    'length': 0.25,
    'reference': 0.25
}

# 1. Data loading
def load_data(full_path: str, niche_path: str) -> (pd.DataFrame, pd.DataFrame):
    """
    Load the full catalog and niche dataset from Excel files.
    Returns two DataFrames: full_df, niche_df.
    """
    full_df = pd.read_excel(full_path)
    niche_df = pd.read_excel(niche_path)
    return full_df, niche_df

# 2. Preprocessing
def preprocess(df: pd.DataFrame) -> pd.DataFrame:
    """
    Parse genres, ensure pages numeric, assign size buckets.
    """
    df['genre_list'] = df['genre'].str.split(',')
    df['num_pages'] = pd.to_numeric(df['num_pages'], errors='coerce')

    def assign_bucket(pages):
        for label, (lo, hi) in SIZE_BUCKETS.items():
            if lo <= pages < hi:
                return label
        return None

    df['size_bucket'] = df['num_pages'].apply(assign_bucket)
    return df

# 3. User input handling
def get_user_preferences(genres: list, full_df: pd.DataFrame) -> dict:
    """
    Prompt user for preferred genres, size bucket, and perform reference rounds.
    Returns a dict with keys: 'genres', 'size_bucket', 'references'.
    """
    prefs = {'genres': [], 'size_bucket': None, 'references': []}

    # Program introduction
    print("\nWelcome to the Niche Book Recommender!")
    print("We will suggest high-quality niche books based on your preferred genres, desired length, and sample choices.\n")

    # 3.1 Genre selection
    print("Available genres:")
    for idx, g in enumerate(genres, start=1):
        print(f"{idx}. {g}")
    sel = input("Select one or more genres by number (comma-separated): ")
    while True:
        try:
            choices = [int(x.strip()) for x in sel.split(',')]
            prefs['genres'] = [genres[i-1] for i in choices]
            break
        except Exception:
            sel = input("Invalid selection. Enter genre numbers separated by commas: ")

    # 3.2 Size bucket selection
    print("\nSize buckets (page ranges):")
    for idx, (label, (lo, hi)) in enumerate(SIZE_BUCKETS.items(), start=1):
        hi_display = f"{int(hi)}" if np.isfinite(hi) else "and above"
        print(f"{idx}. {label} ({int(lo)} to {hi_display} pages)")
    sb = input("Select a size bucket by number: ")
    while True:
        try:
            i = int(sb.strip())
            key = list(SIZE_BUCKETS.keys())[i-1]
            prefs['size_bucket'] = key
            break
        except Exception:
            sb = input("Invalid selection. Enter the number for your size bucket: ")

    # 3.3 Reference-book rounds
    previous_choice = None
    for round_num in range(1, 4):
        mask_genre = full_df['genre_list'].apply(lambda gl: bool(set(gl) & set(prefs['genres'])))
        mask_bucket = full_df['size_bucket'] == prefs['size_bucket']
        candidates_df = full_df[mask_genre & mask_bucket].copy()
        if 'ratings_count' in candidates_df.columns:
            candidates_df = candidates_df.sort_values('ratings_count', ascending=False)
        top_df = candidates_df.head(50)

        if previous_choice is not None and prefs['references']:
            chosen = prefs['references'][-1]
            pool = top_df[top_df.index != chosen.name]
            pair = pd.concat([chosen.to_frame().T, pool.sample(1)])
        else:
            pair = top_df.sample(2)

        pair = pair.reset_index(drop=True)
        print(f"\nRound {round_num}: choose a book or enter 'n' if you haven't read either:")
        for idx, row in pair.iterrows():
            print(f"{idx+1}. {row['title']} by {row['authors']} ({int(row['num_pages'])} pages)")
        choice = input("Enter 1 or 2, or 'n': ")
        while choice not in ['1', '2', 'n']:
            choice = input("Invalid. Enter 1, 2, or 'n': ")
        if choice in ['1', '2']:
            sel_row = pair.iloc[int(choice)-1]
            prefs['references'].append(sel_row)
            previous_choice = sel_row
        else:
            print("No reference selected this round.")

    return prefs

# 4. Build user profile
def build_user_profile(prefs: dict, full_df: pd.DataFrame) -> dict:
    mlb = MultiLabelBinarizer()
    mlb.fit(full_df['genre_list'].dropna())
    user_genre_vec = mlb.transform([prefs['genres']])[0]

    scaler = MinMaxScaler()
    scaler.fit(full_df['num_pages'].values.reshape(-1, 1))
    lo, hi = SIZE_BUCKETS[prefs['size_bucket']]
    if np.isinf(hi):
        hi = full_df['num_pages'].max()
    midpoint = (lo + hi) / 2
    length_target = scaler.transform([[midpoint]])[0][0]

    ref_vecs = []
    for ref in prefs['references']:
        g_vec = mlb.transform([ref['genre_list']])[0]
        p_norm = scaler.transform([[ref['num_pages']]])[0][0]
        ref_vecs.append(np.concatenate([g_vec, [p_norm]]))
    reference_centroid = np.mean(ref_vecs, axis=0) if ref_vecs else np.zeros(len(mlb.classes_) + 1)

    return {
        'mlb': mlb,
        'scaler': scaler,
        'genre_vector': user_genre_vec,
        'length_target': length_target,
        'reference_centroid': reference_centroid,
        'size_bucket': prefs['size_bucket']
    }

# 5. Scoring candidates
def score_candidates(niche_df: pd.DataFrame, profile: dict, weights: dict) -> pd.DataFrame:
    scored = niche_df.copy()
    mlb = profile['mlb']
    scaler = profile['scaler']
    user_genre_vec = profile['genre_vector']
    size_bucket = profile['size_bucket']
    ref_centroid = profile['reference_centroid']
    has_ref = np.linalg.norm(ref_centroid) > 0

    def compute_score(row):
        book_genre_vec = mlb.transform([row['genre_list']])[0]
        genre_score = np.dot(book_genre_vec, user_genre_vec) / user_genre_vec.sum() if user_genre_vec.sum()>0 else 0.0

        pages = row['num_pages']
        lo, hi = SIZE_BUCKETS[size_bucket]
        if lo <= pages < hi:
            length_score = 1.0
        else:
            span = lo if np.isinf(hi) else hi-lo
            dist = lo-pages if pages<lo else pages-hi
            length_score = max(0.0, 1 - (dist/span))

        if has_ref:
            book_vec = np.concatenate([book_genre_vec, [scaler.transform([[pages]])[0][0]]])
            ref_sim = 1 - cosine(book_vec, ref_centroid)
            ref_score = 0.0 if np.isnan(ref_sim) else ref_sim
        else:
            ref_score = 0.0

        return (weights['genre']*genre_score + weights['length']*length_score + weights['reference']*ref_score)

    scored['score'] = scored.apply(compute_score, axis=1)
    return scored


# 6. Select top N (tie-break by average rating)
def select_top_n(scored_df: pd.DataFrame, n: int = 10) -> pd.DataFrame:
    # Sort by score (desc) and then by average_rating (desc)
    return (
        scored_df
        .sort_values(by=['score', 'average_rating'], ascending=[False, False])
        .head(n)
    )


# 7. Main
def main():
    full_df, niche_df = load_data('books.xlsx', 'over 4 and under 200.xlsx')

    full_df = preprocess(full_df)
    niche_df = preprocess(niche_df)

    all_genres = sorted({g for sub in full_df['genre_list'].dropna() for g in sub})
    prefs = get_user_preferences(all_genres, full_df)

    profile = build_user_profile(prefs, full_df)
    scored = score_candidates(niche_df, profile, WEIGHTS)
    recommendations = select_top_n(scored)

    # Explanation of calculation
    print("\nCalculation details:")
    print(f"Genre weight: {WEIGHTS['genre']}")
    print(f"Length weight: {WEIGHTS['length']}")
    print(f"Reference weight: {WEIGHTS['reference']}\n")
    print(f"Selected genres: {prefs['genres']}")
    print(f"Selected size bucket: {prefs['size_bucket']}\n")
    if prefs['references']:
        print("Reference books chosen:")
        for ref in prefs['references']:
            print(f" - {ref['title']} by {ref['authors']}")
    else:
        print("No reference books selected.")

    # Final recommendations
    print("\nBased on your selections, here are the recommended niche books:\n")
    results_df = recommendations[['title', 'authors', 'average_rating', 'num_pages', 'genre_list', 'score']]
    print(results_df.to_string(index=False))

if __name__ == '__main__':
    main()
# Out:
# Welcome to the Niche Book Recommender!
# We will suggest high-quality niche books based on your preferred genres, desired length, and sample choices.
#
# Available genres:
# 1.  19th Century
# 2.  20th Century
# 3.  40k
# 4.  Abuse
# 5.  Academia
# 6.  Academic
# 7.  Academics
# 8.  Action
# 9.  Adoption
# 10.  Adult
# 11.  Adult Fiction
# 12.  Adventure
# 13.  Africa
# 14.  African American
# 15.  African American Literature
# 16.  African Literature
# 17.  Agatha Christie
# 18.  Alchemy
# 19.  Algorithms
# 20.  Aliens
# 21.  Alternate History
# 22.  Amazon
# 23.  American
# 24.  American Civil War
# 25.  American History
# 26.  American Revolution
# 27.  Americana
# 28.  Ancient
# 29.  Ancient History
# 30.  Animals
# 31.  Anime
# 32.  Anthologies
# 33.  Anthropology
# 34.  Apocalyptic
# 35.  Archaeology
# 36.  Architecture
# 37.  Art
# 38.  Art Design
# 39.  Art History
# 40.  Arthurian
# 41.  Artificial Intelligence
# 42.  Astronomy
# 43.  Atheism
# 44.  Audiobook
# 45.  Australia
# 46.  Autistic Spectrum Disorder
# 47.  Autobiography
# 48.  Aviation
# 49.  BDSM
# 50.  Baseball
# 51.  Basketball
# 52.  Batman
# 53.  Beading
# 54.  Biography
# 55.  Biography Memoir
# 56.  Biology
# 57.  Birds
# 58.  Bizarro Fiction
# 59.  Book Club
# 60.  Books About Books
# 61.  Brazil
# 62.  Brewing
# 63.  British Literature
# 64.  Buddhism
# 65.  Buffy The Vampire Slayer
# 66.  Business
# 67.  Canada
# 68.  Category Romance
# 69.  Catholic
# 70.  Cats
# 71.  Chapter Books
# 72.  Chick Lit
# 73.  Childrens
# 74.  China
# 75.  Christian
# 76.  Christian Fiction
# 77.  Christian Living
# 78.  Christianity
# 79.  Christmas
# 80.  Church
# 81.  Church History
# 82.  Civil War
# 83.  Classical Studies
# 84.  Classics
# 85.  Coding
# 86.  Collections
# 87.  Comedy
# 88.  Comic Book
# 89.  Comic Strips
# 90.  Comics
# 91.  Comics Manga
# 92.  Coming Of Age
# 93.  Communication
# 94.  Computer Science
# 95.  Computers
# 96.  Conspiracy Theories
# 97.  Contemporary
# 98.  Contemporary Romance
# 99.  Cookbooks
# 100.  Cooking
# 101.  Counselling
# 102.  Counting
# 103.  Cozy
# 104.  Cozy Mystery
# 105.  Crafts
# 106.  Crime
# 107.  Criticism
# 108.  Cthulhu Mythos
# 109.  Cults
# 110.  Cultural
# 111.  Cyberpunk
# 112.  Czech Literature
# 113.  Dark
# 114.  Dark Academia
# 115.  Dark Fantasy
# 116.  Dark Romance
# 117.  Dc Comics
# 118.  Death
# 119.  Design
# 120.  Detective
# 121.  Diary
# 122.  Dictionaries
# 123.  Dinosaurs
# 124.  Disability
# 125.  Dogs
# 126.  Dragonlance
# 127.  Dragons
# 128.  Drama
# 129.  Drawing
# 130.  Dungeons and Dragons
# 131.  Dutch Literature
# 132.  Dystopia
# 133.  Economics
# 134.  Education
# 135.  Egypt
# 136.  Emotion
# 137.  Enemies To Lovers
# 138.  English Literature
# 139.  Entrepreneurship
# 140.  Environment
# 141.  Epic Fantasy
# 142.  Erotic Romance
# 143.  Erotica
# 144.  Espionage
# 145.  Essays
# 146.  European History
# 147.  Evangelism
# 148.  Evolution
# 149.  Fairy Tales
# 150.  Faith
# 151.  Family
# 152.  Fantasy
# 153.  Fantasy Romance
# 154.  Fashion
# 155.  Feminism
# 156.  Fiction
# 157.  Film
# 158.  Finance
# 159.  Firefighters
# 160.  Fitness
# 161.  Folklore
# 162.  Food
# 163.  Food and Wine
# 164.  Forgotten Realms
# 165.  France
# 166.  French Literature
# 167.  French Revolution
# 168.  Friendship
# 169.  Games
# 170.  Gaming
# 171.  Gardening
# 172.  Gay
# 173.  Gay Fiction
# 174.  Gender
# 175.  Geoffrey Chaucer
# 176.  Geology
# 177.  German Literature
# 178.  Germany
# 179.  Ghosts
# 180.  Goth
# 181.  Gothic
# 182.  Graphic Novels
# 183.  Graphic Novels Comics
# 184.  Graphic Novels Manga
# 185.  Greece
# 186.  Greek Mythology
# 187.  Grief
# 188.  Halloween
# 189.  Harlequin
# 190.  Harlequin Blaze
# 191.  Harlequin Desire
# 192.  Harlequin Presents
# 193.  Harlequin Romance
# 194.  Health
# 195.  Herbs
# 196.  High Fantasy
# 197.  High School
# 198.  Historical
# 199.  Historical Fiction
# 200.  Historical Mystery
# 201.  Historical Romance
# 202.  History
# 203.  Holiday
# 204.  Holocaust
# 205.  Horror
# 206.  Horror Thriller
# 207.  Horses
# 208.  How To
# 209.  Hqn
# 210.  Hugo Awards
# 211.  Humor
# 212.  India
# 213.  Indian Literature
# 214.  Indigenous
# 215.  Inspirational
# 216.  Iran
# 217.  Ireland
# 218.  Irish Literature
# 219.  Islam
# 220.  Israel
# 221.  Italian Literature
# 222.  Italy
# 223.  Japan
# 224.  Japanese Literature
# 225.  Jewish
# 226.  Josei
# 227.  Journalism
# 228.  Judaica
# 229.  Judaism
# 230.  Juvenile
# 231.  Knitting
# 232.  LGBT
# 233.  Language
# 234.  Latin American
# 235.  Law
# 236.  Lds
# 237.  Leadership
# 238.  Legal Thriller
# 239.  Lesbian
# 240.  Light Novel
# 241.  Linguistics
# 242.  Literary Criticism
# 243.  Literary Fiction
# 244.  Literature
# 245.  Logic
# 246.  Love
# 247.  Lovecraftian
# 248.  M M Romance
# 249.  Mafia Romance
# 250.  Magic
# 251.  Magical Realism
# 252.  Magick
# 253.  Management
# 254.  Manga
# 255.  Manhwa
# 256.  Martial Arts
# 257.  Marvel
# 258.  Mathematics
# 259.  Media Tie In
# 260.  Medical
# 261.  Medicine
# 262.  Medieval
# 263.  Memoir
# 264.  Menage
# 265.  Mental Health
# 266.  Mental Illness
# 267.  Metaphysics
# 268.  Middle Grade
# 269.  Military Fiction
# 270.  Military History
# 271.  Military Science Fiction
# 272.  Money
# 273.  Morocco
# 274.  Mountaineering
# 275.  Murder Mystery
# 276.  Music
# 277.  Mystery
# 278.  Mystery Thriller
# 279.  Mysticism
# 280.  Mythology
# 281.  Native American
# 282.  Nature
# 283.  Naval History
# 284.  Neuroscience
# 285.  New Adult
# 286.  New Age
# 287.  New Testament
# 288.  New York
# 289.  Nigeria
# 290.  Nobel Prize
# 291.  Noir
# 292.  Nonfiction
# 293.  Novella
# 294.  Novels
# 295.  Nutrition
# 296.  Occult
# 297.  Old Testament
# 298.  Own
# 299.  Paganism
# 300.  Paranormal
# 301.  Paranormal Romance
# 302.  Parenting
# 303.  Personal Development
# 304.  Personal Finance
# 305.  Philosophy
# 306.  Photography
# 307.  Physics
# 308.  Picture Books
# 309.  Pirates
# 310.  Plays
# 311.  Poetry
# 312.  Poland
# 313.  Polish Literature
# 314.  Political Science
# 315.  Politics
# 316.  Pop Culture
# 317.  Popular Science
# 318.  Portugal
# 319.  Portuguese Literature
# 320.  Post Apocalyptic
# 321.  Prayer
# 322.  Presidents
# 323.  Productivity
# 324.  Programming
# 325.  Psychoanalysis
# 326.  Psychology
# 327.  Pulp
# 328.  Pulp Adventure
# 329.  Queer
# 330.  Quilting
# 331.  Race
# 332.  Read For School
# 333.  Realistic Fiction
# 334.  Reference
# 335.  Regency
# 336.  Relationships
# 337.  Religion
# 338.  Retellings
# 339.  Robots
# 340.  Rock N Roll
# 341.  Role Playing Games
# 342.  Romance
# 343.  Romania
# 344.  Romanian Literature
# 345.  Romantasy
# 346.  Romantic Suspense
# 347.  Romanticism
# 348.  Russia
# 349.  Russian History
# 350.  Russian Literature
# 351.  Scandinavian Literature
# 352.  School
# 353.  School Stories
# 354.  Science
# 355.  Science Fiction
# 356.  Science Fiction Fantasy
# 357.  Scotland
# 358.  Scripture
# 359.  Second Chance
# 360.  Seinen
# 361.  Self Help
# 362.  Semiotics
# 363.  Sewing
# 364.  Sexuality
# 365.  Shapeshifters
# 366.  Shojo
# 367.  Shonen
# 368.  Short Stories
# 369.  Short Story Collection
# 370.  Skepticism
# 371.  Soccer
# 372.  Social Justice
# 373.  Social Media
# 374.  Sociology
# 375.  Software
# 376.  South Africa
# 377.  Southern
# 378.  Southern Gothic
# 379.  Space
# 380.  Space Opera
# 381.  Spain
# 382.  Spanish Literature
# 383.  Speculative Fiction
# 384.  Spider Man
# 385.  Spirituality
# 386.  Sports
# 387.  Star Trek Voyager
# 388.  Star Wars
# 389.  Steampunk
# 390.  Storytime
# 391.  Superheroes
# 392.  Superman
# 393.  Supernatural
# 394.  Survival
# 395.  Suspense
# 396.  Sustainability
# 397.  Swedish Literature
# 398.  Sword and Planet
# 399.  Sword and Sorcery
# 400.  Teaching
# 401.  Technical
# 402.  Technology
# 403.  Teen
# 404.  Terrorism
# 405.  Textbooks
# 406.  The United States Of America
# 407.  The World
# 408.  Theatre
# 409.  Theology
# 410.  Theory
# 411.  Thriller
# 412.  Time Travel
# 413.  Tragedy
# 414.  Transport
# 415.  Travel
# 416.  Trivia
# 417.  True Crime
# 418.  Tudor Period
# 419.  Turkish
# 420.  Turkish Literature
# 421.  Tv
# 422.  Ukraine
# 423.  Urban
# 424.  Urban Fantasy
# 425.  Urban Planning
# 426.  Urbanism
# 427.  Vampires
# 428.  Vegan
# 429.  Victor Frankenstein
# 430.  Victorian
# 431.  Video Games
# 432.  War
# 433.  Web
# 434.  Website Design
# 435.  Western Romance
# 436.  Westerns
# 437.  Witchcraft
# 438.  Witches
# 439.  Wolves
# 440.  Womens
# 441.  World Of Darkness
# 442.  World War I
# 443.  World War II
# 444.  Writing
# 445.  Yaoi
# 446.  Young Adult
# 447.  Zen
# 448.  Zombies
# 449. Action
# 450. Adoption
# 451. Adventure
# 452. Africa
# 453. African American
# 454. African American Romance
# 455. Agatha Christie
# 456. Aliens
# 457. Alternate History
# 458. American History
# 459. Animals
# 460. Anthologies
# 461. Anthropology
# 462. Architecture
# 463. Art
# 464. Art History
# 465. Asia
# 466. Astronomy
# 467. Audiobook
# 468. Australia
# 469. Baseball
# 470. Batman
# 471. Biography
# 472. Biology
# 473. Birds
# 474. Bizarro Fiction
# 475. Book Club
# 476. Books About Books
# 477. Buddhism
# 478. Buffy The Vampire Slayer
# 479. Business
# 480. Catholic
# 481. Chess
# 482. Chick Lit
# 483. Childrens
# 484. China
# 485. Christian
# 486. Christian Fiction
# 487. Christian Living
# 488. Christianity
# 489. Christmas
# 490. Church
# 491. Civil War
# 492. Classic Literature
# 493. Classics
# 494. Comedy
# 495. Comics
# 496. Computer Science
# 497. Computers
# 498. Contemporary
# 499. Contemporary Romance
# 500. Cookbooks
# 501. Cooking
# 502. Counselling
# 503. Cozy Mystery
# 504. Crafts
# 505. Crime
# 506. Criticism
# 507. Cyberpunk
# 508. Dark Romance
# 509. Design
# 510. Disability
# 511. Divination
# 512. Doctor Who
# 513. Dogs
# 514. Dragonlance
# 515. Drama
# 516. Dungeons and Dragons
# 517. Ecology
# 518. Economics
# 519. Education
# 520. Egypt
# 521. Engineering
# 522. Erotica
# 523. Essays
# 524. Fantasy
# 525. Fashion
# 526. Feminism
# 527. Fiction
# 528. Film
# 529. Finance
# 530. Fitness
# 531. Food
# 532. Football
# 533. Forgotten Realms
# 534. France
# 535. French Literature
# 536. Game Design
# 537. Games
# 538. Gaming
# 539. Gardening
# 540. Gay
# 541. Geography
# 542. German Literature
# 543. Gothic
# 544. Graphic Novels
# 545. Halloween
# 546. Harlequin
# 547. Harlequin Desire
# 548. Harlequin Presents
# 549. Health
# 550. Historical
# 551. Historical Fiction
# 552. Historical Romance
# 553. History
# 554. Horror
# 555. Horses
# 556. Humor
# 557. India
# 558. Iran
# 559. Islam
# 560. Israel
# 561. Italian Literature
# 562. Italy
# 563. Japan
# 564. Jewellery
# 565. Judaism
# 566. LGBT
# 567. Language
# 568. Law
# 569. Leadership
# 570. Lesbian
# 571. Linguistics
# 572. Literary Criticism
# 573. Literature
# 574. Love Inspired
# 575. Management
# 576. Manga
# 577. Marriage
# 578. Mathematics
# 579. Medicine
# 580. Memoir
# 581. Middle Grade
# 582. Military Fiction
# 583. Morocco
# 584. Music
# 585. Mystery
# 586. Mythology
# 587. Native American
# 588. Nature
# 589. New York
# 590. Noir
# 591. Nonfiction
# 592. Not found
# 593. Novels
# 594. Occult
# 595. Paranormal
# 596. Paranormal Romance
# 597. Parenting
# 598. Personal Development
# 599. Philosophy
# 600. Photography
# 601. Physics
# 602. Picture Books
# 603. Pirates
# 604. Plays
# 605. Poetry
# 606. Politics
# 607. Post Apocalyptic
# 608. Presidents
# 609. Productivity
# 610. Programming
# 611. Psychology
# 612. Pulp
# 613. Queer
# 614. Quilting
# 615. Realistic Fiction
# 616. Reference
# 617. Regency
# 618. Relationships
# 619. Religion
# 620. Reverse Harem
# 621. Role Playing Games
# 622. Romance
# 623. Romantasy
# 624. Romantic Suspense
# 625. Russia
# 626. Russian Literature
# 627. Science
# 628. Science Fiction
# 629. Science Fiction Fantasy
# 630. Scotland
# 631. Self Help
# 632. Sewing
# 633. Sexuality
# 634. Short Stories
# 635. Sociology
# 636. Space
# 637. Spain
# 638. Spanish Literature
# 639. Spirituality
# 640. Sports
# 641. Star Trek
# 642. Star Wars
# 643. Suspense
# 644. Technical
# 645. Theatre
# 646. Theology
# 647. Thriller
# 648. Time Travel
# 649. Travel
# 650. True Crime
# 651. Unknown
# 652. Urban
# 653. Urban Fantasy
# 654. Urban Planning
# 655. Vampires
# 656. Video Games
# 657. Warcraft
# 658. Westerns
# 659. Wine
# 660. World Of Darkness
# 661. Writing
# 662. Yaoi
# 663. Young Adult
#
# Size buckets (page ranges):
# 1. short (0 to 250 pages)
# 2. medium (250 to 500 pages)
# 3. long (500 to 700 pages)
# 4. extra_long (700 to and above pages)
#
# Round 1: choose a book or enter 'n' if you haven't read either:
# 1. In the Land of White Death: An Epic Story of Survival in the Siberian Arctic by Valerian Albanov/Jon Krakauer/David  Roberts/Alison Anderson/Валериан Альбанов (288 pages)
# 2. 魔戒二部曲：雙城奇謀 by J.R.R. Tolkien/托爾金/Alan  Lee/朱學恆 (467 pages)
#
# Round 2: choose a book or enter 'n' if you haven't read either:
# 1. In the Land of White Death: An Epic Story of Survival in the Siberian Arctic by Valerian Albanov/Jon Krakauer/David  Roberts/Alison Anderson/Валериан Альбанов (288 pages)
# 2. The Sea Hunters II (The Sea Hunters  #2) by Clive Cussler/Craig Dirgo (464 pages)
#
# Round 3: choose a book or enter 'n' if you haven't read either:
# 1. The Sea Hunters II (The Sea Hunters  #2) by Clive Cussler/Craig Dirgo (464 pages)
# 2. White Fang by Jack London (252 pages)
#
# Calculation details:
# Genre weight: 0.5
# Length weight: 0.25
# Reference weight: 0.25
#
# Selected genres: [' Adventure']
# Selected size bucket: medium
#
# Reference books chosen:
#  - In the Land of White Death: An Epic Story of Survival in the Siberian Arctic by Valerian Albanov/Jon Krakauer/David  Roberts/Alison Anderson/Валериан Альбанов
#  - The Sea Hunters II (The Sea Hunters  #2) by Clive Cussler/Craig Dirgo
#  - White Fang by Jack London
#
# Based on your selections, here are the recommended niche books:
#
#                                                                                  title                                                     authors  average_rating  num_pages                             genre_list    score
#                                           Les Deux Tours (Le Seigneur des Anneaux  #2)                               J.R.R. Tolkien/Francis Ledoux            4.44        471        [Fantasy,  Fiction,  Adventure] 0.849556
#                                                                             魔戒二部曲：雙城奇謀                            J.R.R. Tolkien/托爾金/Alan  Lee/朱學恆            4.44        467        [Fantasy,  Fiction,  Adventure] 0.849554
#                                           Treasure Island (Great Illustrated Classics)     Deidre S. Laiken/A.J. McAllister/Robert Louis Stevenson            4.05        232       [Classics,  Fiction,  Adventure] 0.831437
#                               Cloak and Dagger (Tom Clancy's Net Force Explorers  #17)       John Helfers/Russell Davis/Tom Clancy/Steve Pieczenik            4.00        208              [Young Adult,  Adventure] 0.829757
#                                    Death Match (Tom Clancy's Net Force Explorers  #18)                      Diane Duane/Tom Clancy/Steve Pieczenik            4.17        192    [Fiction,  Adventure,  Young Adult] 0.824501
#                                  Treasure Island #2: Off to Sea (Easy Reader Classics) Catherine Nichols/Sally Wern Comport/Robert Louis Stevenson            4.17         32       [Classics,  Fiction,  Adventure] 0.631303
#                                     The Return of the King (The Lord of the Rings  #3)                                 Brian Sibley/J.R.R. Tolkien            4.35          1        [Fantasy,  Fiction,  Adventure] 0.600280
# Jack London Illustrated: The Call of the Wild/White Fang/The Sea-Wolf/40 Short Stories                                                 Jack London            4.26        761 [Classics,  Short Stories,  Adventure] 0.599642
#                  A People's History of the United States: The Civil War to the Present                 Howard Zinn/Kathy Emery/Ellen Gordon Reeves            4.00        496                 [Nonfiction,  History] 0.412358
#                             The Hot Zone: The Chilling True Story of an Ebola Outbreak                                           Richard   Preston            4.12        384       [Nonfiction,  Science,  History] 0.382592
